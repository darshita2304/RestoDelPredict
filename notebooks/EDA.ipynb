# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/restaurant.csv')

# %%
df.head(10)
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
# 5  0x3af3      MUMRES15DEL03                 29.0                      4.5
# 6  0x3aab      MYSRES01DEL01                 35.0                      4.0
# 7  0x689b     PUNERES20DEL01                 33.0                      4.2
# 8  0x6f67      HYDRES14DEL01                 34.0                      4.9
# 9  0xc9cf      KOLRES15DEL03                 21.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
# 5            19.176269             72.836721                   19.266269
# 6            12.311072             76.654878                   12.351072
# 7            18.592718             73.773572                   18.702718
# 8            17.426228             78.407495                   17.496228
# 9            22.552672             88.352885                   22.582672
#
#    Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106   12-02-22       21:55             22:10  \
# 1                    76.347589   13-02-22       14:55             15:05
# 2                    74.006619   04-03-22       17:30             17:40
# 3                    75.829346   13-02-22        9:20              9:30
# 4                    80.502929   14-02-22       19:50             20:05
# 5                    72.926721   02-04-22       20:25             20:35
# 6                    76.694878   01-03-22       14:55             15:10
# 7                    73.883572   16-03-22       20:30             20:40
# 8                    78.477495   20-03-22       20:40             20:50
# 9                    88.382885   15-02-22       21:15             21:30
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order
# 0                Fog                  Jam                  2         Snack  \
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
# 5         Sandstorms                  Jam                  2        Buffet
# 6              Windy                 High                  1          Meal
# 7         Sandstorms                  Jam                  2         Snack
# 8             Cloudy                  Jam                  0         Snack
# 9              Windy                  Jam                  0          Meal
#
#     Type_of_vehicle  multiple_deliveries Festival           City
# 0        motorcycle                  3.0       No  Metropolitian  \
# 1        motorcycle                  1.0       No  Metropolitian
# 2           scooter                  1.0       No  Metropolitian
# 3        motorcycle                  0.0       No  Metropolitian
# 4           scooter                  1.0       No  Metropolitian
# 5  electric_scooter                  1.0       No  Metropolitian
# 6           scooter                  1.0       No  Metropolitian
# 7        motorcycle                  1.0       No  Metropolitian
# 8        motorcycle                  NaN       No  Metropolitian
# 9        motorcycle                  1.0       No          Urban
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41
# 5                20
# 6                33
# 7                40
# 8                41
# 9                15

# %%
df['Vehicle_condition'].unique()
# Out:
# array([2, 1, 0, 3], dtype=int64)

# %%
df['multiple_deliveries'].unique()
# Out:
# array([3., 1., 0., 2.])

# %%
df.shape
# Out:
# (45584, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
#  12  Road_traffic_density         44983 non-null  object
#  13  Vehicle_condition            45584 non-null  int64
#  14  Type_of_order                45584 non-null  object
#  15  Type_of_vehicle              45584 non-null  object
#  16  multiple_deliveries          44591 non-null  float64
#  17  Festival                     45356 non-null  object
#  18  City                         44384 non-null  object
#  19  Time_taken (min)             45584 non-null  int64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 7.0+ MB

# %%
df.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# count         43730.000000             43676.000000         45584.000000  \
# mean             29.566911                 4.633774            17.017948
# std               5.815064                 0.334744             8.185674
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.500000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              35.000000                 4.900000            22.728163
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude
# count          45584.000000                45584.000000  \
# mean              70.229684                   17.465480
# std               22.885575                    7.335562
# min              -88.366217                    0.010000
# 25%               73.170000                   12.988453
# 50%               75.897963                   18.633934
# 75%               78.044095                   22.785049
# max               88.433452                   31.054057
#
#        Delivery_location_longitude  Vehicle_condition  multiple_deliveries
# count                 45584.000000       45584.000000         44591.000000  \
# mean                     70.844161           1.023385             0.744635
# std                      21.120578           0.839055             0.572510
# min                       0.010000           0.000000             0.000000
# 25%                      73.280000           0.000000             0.000000
# 50%                      76.002574           1.000000             1.000000
# 75%                      78.107044           2.000000             1.000000
# max                      88.563452           3.000000             3.000000
#
#        Time_taken (min)
# count      45584.000000
# mean          26.293963
# std            9.384298
# min           10.000000
# 25%           19.000000
# 50%           26.000000
# 75%           32.000000
# max           54.000000

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# here row id is not required drop it
df.drop(columns=['ID'], inplace=True)

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0      DEHRES17DEL01                 36.0                      4.2  \
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106   12-02-22       21:55             22:10  \
# 1                    76.347589   13-02-22       14:55             15:05
# 2                    74.006619   04-03-22       17:30             17:40
# 3                    75.829346   13-02-22        9:20              9:30
# 4                    80.502929   14-02-22       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order
# 0                Fog                  Jam                  2         Snack  \
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City
# 0      motorcycle                  3.0       No  Metropolitian  \
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
# work on age column as it has many null values - taking average age for null values
df['Delivery_person_Age'].fillna(df['Delivery_person_Age'].mean(), inplace=True)

# %%
#working on Delivery_person_Ratings as it has also manu null values - taking average for null values
df['Delivery_person_Ratings'].fillna(df['Delivery_person_Ratings'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
copy_df = df

# %%
# assiging null values of time ordered to time_order_picked up
df.loc[df['Time_Orderd'].isnull(),'Time_Orderd'] = df['Time_Order_picked']

# %%
# df = copy_df

# %%
df['Time_Orderd_hh']= df["Time_Orderd"].str.split(":").str[0].fillna(0)
df['Time_Orderd_mm'] = df["Time_Orderd"].str.split(":").str[1].fillna(0)

df['Time_Order_picked_hh']= df["Time_Order_picked"].str.split(":").str[0].fillna(0)
df['Time_Order_picked_mm'] = df["Time_Order_picked"].str.split(":").str[1].fillna(0)

# %%
df['Time_Orderd_hh'].unique()
df['Time_Orderd_mm'].unique()
df['Time_Order_picked_hh'].unique()
df['Time_Order_picked_mm'].unique()

df['Time_Orderd_hh'] = df['Time_Orderd_hh'].astype(float)
df['Time_Orderd_mm'] = df['Time_Orderd_mm'].astype(float)
df['Time_Order_picked_hh'] = df['Time_Order_picked_hh'].astype(float)
df['Time_Order_picked_hh'] = df['Time_Order_picked_hh'].astype(float)


df['Time_Orderd_hh'] = df['Time_Orderd_hh'].astype(int)
df['Time_Orderd_mm'] = df['Time_Orderd_mm'].astype(int)
df['Time_Order_picked_hh'] = df['Time_Order_picked_hh'].astype(int)
df['Time_Order_picked_hh'] = df['Time_Order_picked_hh'].astype(int)

# %%
df.loc[df['Time_Orderd_hh']==24] # here we hv orderd time is 0 but picked up time is there.. so transfering it
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 339       BANGRES13DEL02            29.566911                 4.633774  \
# 718      COIMBRES07DEL03            29.566911                 4.633774
# 1070      BANGRES18DEL01            29.566911                 4.633774
# 1254       DEHRES14DEL03            29.566911                 4.633774
# 1660    RANCHIRES19DEL03            29.566911                 4.633774
# 3092      AURGRES13DEL03            29.566911                 4.633774
# 3265       MYSRES15DEL02            29.566911                 4.633774
# 5712      PUNERES19DEL03            29.566911                 4.633774
# 6014      CHENRES02DEL03            29.566911                 4.633774
# 6809    COIMBRES010DEL01            29.566911                 4.633774
# 9678       VADRES02DEL02            29.566911                 4.633774
# 10317     BANGRES13DEL03            29.566911                 4.633774
# 11083      SURRES08DEL01            29.566911                 4.633774
# 13737     PUNERES15DEL03            29.566911                 4.633774
# 14613      GOARES14DEL02            29.566911                 4.633774
# 23185      GOARES06DEL01            29.566911                 4.633774
# 23460      SURRES11DEL03            29.566911                 4.633774
# 28868      JAPRES20DEL03            29.566911                 4.633774
# 29380     PUNERES08DEL03            29.566911                 4.633774
# 29531      MYSRES11DEL02            29.566911                 4.633774
# 30092     PUNERES06DEL03            29.566911                 4.633774
# 30227      MUMRES11DEL02            29.566911                 4.633774
# 32076      KNPRES02DEL02            29.566911                 4.633774
# 33148      JAPRES17DEL01            29.566911                 4.633774
# 33192      VADRES16DEL03            29.566911                 4.633774
# 35498      JAPRES11DEL01            29.566911                 4.633774
# 36586     PUNERES19DEL01            29.566911                 4.633774
# 38232      MUMRES03DEL01            29.566911                 4.633774
# 38437      SURRES08DEL02            29.566911                 4.633774
# 38522      GOARES03DEL03            29.566911                 4.633774
# 39687    COIMBRES18DEL02            29.566911                 4.633774
# 40951      BHPRES13DEL01            29.566911                 4.633774
# 41155     LUDHRES18DEL03            29.566911                 4.633774
# 41215      ALHRES11DEL02            29.566911                 4.633774
# 41919      JAPRES11DEL01            29.566911                 4.633774
# 42511     CHENRES17DEL02            29.566911                 4.633774
# 42662      VADRES13DEL01            29.566911                 4.633774
# 43559     CHENRES20DEL01            29.566911                 4.633774
# 44005     AURGRES07DEL02            29.566911                 4.633774
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 339              12.935662             77.614130                   13.065662  \
# 718              10.961850             76.971082                   11.021850
# 1070             12.913041             77.683237                   13.023041
# 1254             30.319528             78.040267                   30.349528
# 1660             23.333017             85.317200                   23.393017
# 3092             19.880256             75.323503                   19.970256
# 3265             12.352058             76.606650                   12.402058
# 5712             18.563934             73.915367                   18.623935
# 6014            -13.086438             80.220672                   13.116438
# 6809             11.003008             76.975440                   11.073009
# 9678              0.000000              0.000000                    0.130000
# 10317            12.935662             77.614130                   13.025662
# 11083            21.173343             72.792731                   21.283343
# 13737            18.636215             73.751081                   18.726215
# 14613            15.157944             73.950889                   15.207944
# 23185            15.561550             73.749092                   15.631550
# 23460           -21.157735             72.768778                   21.247735
# 28868           -26.956431             75.776649                   27.096431
# 29380            18.534080             73.898520                   18.624080
# 29531           -12.323225            -76.630028                   12.403225
# 30092            18.546258             73.904337                   18.636258
# 30227            18.994237             72.825553                   19.044237
# 32076            26.471617             80.313564                   26.601617
# 33148            26.892312             75.806896                   27.002312
# 33192             0.000000              0.000000                    0.090000
# 35498           -26.902940            -75.793007                   27.012940
# 36586            18.563934             73.915367                   18.633934
# 38232            19.223840             72.841347                   19.293840
# 38437            21.173343             72.792731                   21.303343
# 38522            15.574828             73.766883                   15.664828
# 39687           -11.020910            -76.940432                   11.100910
# 40951           -23.230791            -77.437020                   23.300791
# 41155           -30.890184            -75.829615                   31.030184
# 41215             0.000000              0.000000                    0.080000
# 41919           -26.902940             75.793007                   27.012940
# 42511            13.045479             80.233110                   13.125479
# 42662            22.310237             73.158921                   22.420237
# 43559            12.975996             80.221898                   13.045996
# 44005            19.875908             75.358888                   20.005908
#
#        Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked
# 339                      77.744130   02-03-22    24:05:00          24:05:00  \
# 718                      77.031082   19-03-22    24:05:00          24:05:00
# 1070                     77.793237   10-03-22    24:05:00          24:05:00
# 1254                     78.070267   17-02-22    24:05:00          24:05:00
# 1660                     85.377200   05-04-22    24:10:00          24:10:00
# 3092                     75.413503   16-02-22    24:05:00          24:05:00
# 3265                     76.656650   30-03-22    24:05:00          24:05:00
# 5712                     73.975367   09-03-22    24:10:00          24:10:00
# 6014                     80.250672   17-03-22    24:15:00          24:15:00
# 6809                     77.045440   18-03-22    24:15:00          24:15:00
# 9678                      0.130000   18-03-22    24:10:00          24:10:00
# 10317                    77.704130   02-04-22    24:10:00          24:10:00
# 11083                    72.902731   29-03-22    24:10:00          24:10:00
# 13737                    73.841081   27-03-22    24:05:00          24:05:00
# 14613                    74.000889   13-02-22    24:10:00          24:10:00
# 23185                    73.819092   18-02-22    24:15:00          24:15:00
# 23460                    72.858778   29-03-22    24:15:00          24:15:00
# 28868                    75.916649   04-03-22    24:10:00          24:10:00
# 29380                    73.988520   04-03-22    24:05:00          24:05:00
# 29531                    76.710028   16-03-22    24:10:00          24:10:00
# 30092                    73.994337   16-03-22    24:05:00          24:05:00
# 30227                    72.875553   01-03-22    24:05:00          24:05:00
# 32076                    80.443564   16-02-22    24:05:00          24:05:00
# 33148                    75.916896   31-03-22    24:05:00          24:05:00
# 33192                     0.090000   02-03-22    24:05:00          24:05:00
# 35498                    75.903007   04-04-22    24:15:00          24:15:00
# 36586                    73.985367   04-04-22    24:15:00          24:15:00
# 38232                    72.911347   14-03-22    24:05:00          24:05:00
# 38437                    72.922731   12-03-22    24:10:00          24:10:00
# 38522                    73.856883   18-02-22    24:05:00          24:05:00
# 39687                    77.020432   31-03-22    24:05:00          24:05:00
# 40951                    77.507020   18-02-22    24:05:00          24:05:00
# 41155                    75.969615   14-02-22    24:15:00          24:15:00
# 41215                     0.080000   16-02-22    24:15:00          24:15:00
# 41919                    75.903007   31-03-22    24:10:00          24:10:00
# 42511                    80.313110   02-04-22    24:10:00          24:10:00
# 42662                    73.268921   02-04-22    24:10:00          24:10:00
# 43559                    80.291898   16-03-22    24:05:00          24:05:00
# 44005                    75.488888   14-02-22    24:10:00          24:10:00
#
#        ... Type_of_order   Type_of_vehicle  multiple_deliveries Festival
# 339    ...        Drinks           scooter                  1.0       No  \
# 718    ...          Meal        motorcycle                  1.0       No
# 1070   ...        Buffet           scooter                  1.0       No
# 1254   ...        Drinks        motorcycle                  0.0       No
# 1660   ...          Meal        motorcycle                  1.0       No
# 3092   ...        Buffet        motorcycle                  0.0       No
# 3265   ...          Meal        motorcycle                  0.0      NaN
# 5712   ...          Meal           bicycle                  0.0       No
# 6014   ...        Drinks           scooter                  1.0       No
# 6809   ...        Drinks        motorcycle                  1.0       No
# 9678   ...        Buffet           scooter                  1.0       No
# 10317  ...        Buffet        motorcycle                  1.0       No
# 11083  ...        Drinks        motorcycle                  1.0       No
# 13737  ...          Meal        motorcycle                  1.0       No
# 14613  ...         Snack           scooter                  1.0       No
# 23185  ...        Buffet        motorcycle                  2.0       No
# 23460  ...        Drinks        motorcycle                  1.0       No
# 28868  ...        Buffet        motorcycle                  0.0       No
# 29380  ...        Drinks           scooter                  1.0       No
# 29531  ...        Drinks        motorcycle                  2.0       No
# 30092  ...        Drinks        motorcycle                  0.0       No
# 30227  ...        Buffet        motorcycle                  0.0       No
# 32076  ...          Meal           scooter                  1.0       No
# 33148  ...          Meal           scooter                  0.0       No
# 33192  ...        Buffet        motorcycle                  0.0       No
# 35498  ...          Meal           scooter                  1.0       No
# 36586  ...          Meal  electric_scooter                  0.0       No
# 38232  ...        Buffet           scooter                  1.0      NaN
# 38437  ...         Snack        motorcycle                  0.0       No
# 38522  ...         Snack        motorcycle                  0.0       No
# 39687  ...          Meal  electric_scooter                  0.0       No
# 40951  ...         Snack        motorcycle                  0.0       No
# 41155  ...         Snack           scooter                  1.0       No
# 41215  ...        Buffet           scooter                  0.0       No
# 41919  ...         Snack        motorcycle                  1.0       No
# 42511  ...         Snack  electric_scooter                  2.0       No
# 42662  ...        Buffet        motorcycle                  1.0       No
# 43559  ...         Snack  electric_scooter                  0.0       No
# 44005  ...         Snack           scooter                  1.0       No
#
#                 City  Time_taken (min) Time_Orderd_hh Time_Orderd_mm
# 339    Metropolitian                26             24              5  \
# 718    Metropolitian                17             24              5
# 1070   Metropolitian                29             24              5
# 1254   Metropolitian                27             24              5
# 1660           Urban                12             24             10
# 3092   Metropolitian                28             24              5
# 3265           Urban                11             24              5
# 5712   Metropolitian                23             24             10
# 6014   Metropolitian                18             24             15
# 6809   Metropolitian                21             24             15
# 9678   Metropolitian                13             24             10
# 10317  Metropolitian                29             24             10
# 11083  Metropolitian                39             24             10
# 13737  Metropolitian                22             24              5
# 14613            NaN                19             24             10
# 23185  Metropolitian                36             24             15
# 23460  Metropolitian                44             24             15
# 28868  Metropolitian                25             24             10
# 29380  Metropolitian                22             24              5
# 29531  Metropolitian                43             24             10
# 30092  Metropolitian                25             24              5
# 30227  Metropolitian                25             24              5
# 32076  Metropolitian                22             24              5
# 33148  Metropolitian                28             24              5
# 33192  Metropolitian                19             24              5
# 35498          Urban                19             24             15
# 36586          Urban                22             24             15
# 38232          Urban                11             24              5
# 38437          Urban                21             24             10
# 38522          Urban                17             24              5
# 39687  Metropolitian                24             24              5
# 40951  Metropolitian                23             24              5
# 41155          Urban                30             24             15
# 41215  Metropolitian                41             24             15
# 41919  Metropolitian                21             24             10
# 42511  Metropolitian                42             24             10
# 42662  Metropolitian                25             24             10
# 43559  Metropolitian                11             24              5
# 44005  Metropolitian                30             24             10
#
#        Time_Order_picked_hh  Time_Order_picked_mm
# 339                      24                    05
# 718                      24                    05
# 1070                     24                    05
# 1254                     24                    05
# 1660                     24                    10
# 3092                     24                    05
# 3265                     24                    05
# 5712                     24                    10
# 6014                     24                    15
# 6809                     24                    15
# 9678                     24                    10
# 10317                    24                    10
# 11083                    24                    10
# 13737                    24                    05
# 14613                    24                    10
# 23185                    24                    15
# 23460                    24                    15
# 28868                    24                    10
# 29380                    24                    05
# 29531                    24                    10
# 30092                    24                    05
# 30227                    24                    05
# 32076                    24                    05
# 33148                    24                    05
# 33192                    24                    05
# 35498                    24                    15
# 36586                    24                    15
# 38232                    24                    05
# 38437                    24                    10
# 38522                    24                    05
# 39687                    24                    05
# 40951                    24                    05
# 41155                    24                    15
# 41215                    24                    15
# 41919                    24                    10
# 42511                    24                    10
# 42662                    24                    10
# 43559                    24                    05
# 44005                    24                    10
#
# [39 rows x 23 columns]

# %%
df.loc[(df['Time_Orderd_hh'] == 0), 'Time_Orderd_hh'] = df['Time_Order_picked_hh']
df.loc[(df['Time_Orderd_hh'] == 24), 'Time_Orderd_hh'] = 0
df.loc[(df['Time_Orderd_mm']==0),'Time_Orderd_mm'] = df['Time_Order_picked_mm']

# %%
df.loc[df['Time_Orderd_hh']==24] # this is row which had both values are wrong.. ordered and pickedup.. so need to drop this rows...
# Out:
# Empty DataFrame
# Columns: [Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_Date, Time_Orderd, Time_Order_picked, Weather_conditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken (min), Time_Orderd_hh, Time_Orderd_mm, Time_Order_picked_hh, Time_Order_picked_mm]
# Index: []
#
# [0 rows x 23 columns]

# %%
indexAge = df[ df['Time_Orderd_hh'] == 0].index

df.drop(indexAge, inplace=True)

# %%
df.loc[df['Time_Orderd_hh']==0]
# Out:
# Empty DataFrame
# Columns: [Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_Date, Time_Orderd, Time_Order_picked, Weather_conditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken (min), Time_Orderd_hh, Time_Orderd_mm, Time_Order_picked_hh, Time_Order_picked_mm]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.loc[df['Time_Order_picked_hh']==0]  # orderd value we hv but pickedup dont hv so considering same..
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 36         KOLRES16DEL02            37.000000                 4.900000  \
# 46       COIMBRES07DEL03            24.000000                 4.700000
# 47         AGRRES12DEL03            39.000000                 4.600000
# 52         MYSRES04DEL03            33.000000                 4.900000
# 57         DEHRES19DEL02            39.000000                 4.900000
# ...                  ...                  ...                      ...
# 45499      HYDRES06DEL01            29.566911                 4.633774
# 45530      JAPRES04DEL02            24.000000                 5.000000
# 45538      GOARES20DEL02            37.000000                 4.300000
# 45566      HYDRES03DEL03            34.000000                 4.900000
# 45577     BANGRES16DEL03            28.000000                 4.900000
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 36               22.539129             88.365507                   22.559129  \
# 46               10.961850             76.971082                   11.051850
# 47               27.165108             78.015053                   27.255108
# 52               12.308500             76.665808                   12.338500
# 57               30.372202             78.077151                   30.422202
# ...                    ...                   ...                         ...
# 45499            17.455894             78.375467                   17.525894
# 45530            26.902328             75.794257                   26.952328
# 45538             0.000000              0.000000                    0.020000
# 45566            17.422819             78.449578                   17.482819
# 45577            13.029198             77.570997                   13.059198
#
#        Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked
# 36                       88.385507   13-02-22       10:55       0.458333333  \
# 46                       77.061082   10-03-22       17:55              0.75
# 47                       78.105053   14-02-22       22:45       0.958333333
# 52                       76.695808   30-03-22       21:55       0.916666667
# 57                       78.127151   15-02-22       20:55             0.875
# ...                            ...        ...         ...               ...
# 45499                    78.445467   23-03-22       17:55              0.75
# 45530                    75.844257   19-03-22       20:50             0.875
# 45538                     0.020000   15-02-22       10:45       0.458333333
# 45566                    78.509578   24-03-22       21:45       0.916666667
# 45577                    77.600997   30-03-22       21:55       0.916666667
#
#        ... Type_of_order Type_of_vehicle  multiple_deliveries Festival
# 36     ...         Snack         scooter                  1.0       No  \
# 46     ...        Buffet      motorcycle                  0.0       No
# 47     ...         Snack      motorcycle                  1.0       No
# 52     ...        Drinks         scooter                  0.0       No
# 57     ...          Meal      motorcycle                  1.0       No
# ...    ...           ...             ...                  ...      ...
# 45499  ...          Meal      motorcycle                  1.0       No
# 45530  ...          Meal         scooter                  1.0       No
# 45538  ...         Snack      motorcycle                  0.0       No
# 45566  ...          Meal      motorcycle                  1.0       No
# 45577  ...          Meal         scooter                  1.0       No
#
#                 City  Time_taken (min) Time_Orderd_hh Time_Orderd_mm
# 36             Urban                16             10             55  \
# 46             Urban                19             17             55
# 47     Metropolitian                27             22             45
# 52     Metropolitian                22             21             55
# 57     Metropolitian                30             20             55
# ...              ...               ...            ...            ...
# 45499          Urban                36             17             55
# 45530  Metropolitian                28             20             50
# 45538  Metropolitian                32             10             45
# 45566  Metropolitian                28             21             45
# 45577  Metropolitian                29             21             55
#
#        Time_Order_picked_hh  Time_Order_picked_mm
# 36                        0                     0
# 46                        0                     0
# 47                        0                     0
# 52                        0                     0
# 57                        0                     0
# ...                     ...                   ...
# 45499                     0                     0
# 45530                     0                     0
# 45538                     0                     0
# 45566                     0                     0
# 45577                     0                     0
#
# [3547 rows x 23 columns]

# %%
df.loc[(df['Time_Order_picked_hh'] == 0), 'Time_Order_picked_hh'] = df['Time_Orderd_hh']
df.loc[(df['Time_Order_picked_hh'] == 24), 'Time_Order_picked_hh'] = 0
df.loc[(df['Time_Order_picked_mm']==0),'Time_Order_picked_mm'] = df['Time_Orderd_mm']

# %%
df.loc[df['Time_Order_picked_hh']==0]
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 66         HYDRES13DEL03                 26.0                      4.7  \
# 92         HYDRES19DEL03                 25.0                      4.8
# 116      COIMBRES12DEL02                 23.0                      4.9
# 316        HYDRES05DEL03                 32.0                      4.9
# 559       BANGRES19DEL01                 23.0                      5.0
# ...                  ...                  ...                      ...
# 45352      SURRES16DEL01                 26.0                      4.9
# 45487     CHENRES09DEL02                 37.0                      4.9
# 45520      HYDRES01DEL02                 26.0                      4.5
# 45522      VADRES17DEL02                 32.0                      4.8
# 45581     CHENRES08DEL03                 30.0                      4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 66               17.431477             78.400350                   17.491477  \
# 92               17.458998             78.500366                   17.488998
# 116              11.000762             76.981876                   11.130762
# 316              17.433809             78.386744                   17.523809
# 559              12.914264             77.678400                   13.024264
# ...                    ...                   ...                         ...
# 45352            21.160437             72.774209                   21.270437
# 45487            13.044694             80.261470                   13.094694
# 45520            17.410371             78.437225                   17.540371
# 45522             0.000000              0.000000                    0.130000
# 45581            13.022394             80.242439                   13.052394
#
#        Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked
# 66                       78.460350   05-03-22       23:50          24:05:00  \
# 92                       78.530366   26-03-22       23:55          24:10:00
# 116                      77.111876   18-03-22           1          24:15:00
# 316                      78.476744   18-03-22       23:55          24:10:00
# 559                      77.788400   23-03-22       23:55          24:05:00
# ...                            ...        ...         ...               ...
# 45352                    72.884209   31-03-22       23:50          24:05:00
# 45487                    80.311470   26-03-22           1          24:15:00
# 45520                    78.567225   25-03-22       23:50          24:05:00
# 45522                     0.130000   10-03-22           1          24:10:00
# 45581                    80.272439   11-03-22       23:50          24:05:00
#
#        ... Type_of_order Type_of_vehicle  multiple_deliveries Festival
# 66     ...        Buffet      motorcycle                  0.0       No  \
# 92     ...         Snack         scooter                  1.0       No
# 116    ...          Meal         scooter                  0.0       No
# 316    ...        Buffet         scooter                  1.0       No
# 559    ...          Meal         scooter                  1.0       No
# ...    ...           ...             ...                  ...      ...
# 45352  ...         Snack      motorcycle                  0.0       No
# 45487  ...         Snack         scooter                  1.0       No
# 45520  ...        Buffet      motorcycle                  0.0       No
# 45522  ...         Snack      motorcycle                  1.0       No
# 45581  ...        Drinks         scooter                  0.0       No
#
#                 City  Time_taken (min) Time_Orderd_hh Time_Orderd_mm
# 66     Metropolitian                10             23             50  \
# 92             Urban                19             23             55
# 116    Metropolitian                18              1             15
# 316    Metropolitian                24             23             55
# 559            Urban                11             23             55
# ...              ...               ...            ...            ...
# 45352  Metropolitian                21             23             50
# 45487            NaN                12              1             15
# 45520  Metropolitian                24             23             50
# 45522          Urban                22              1             10
# 45581  Metropolitian                16             23             50
#
#        Time_Order_picked_hh  Time_Order_picked_mm
# 66                        0                    05
# 92                        0                    10
# 116                       0                    15
# 316                       0                    10
# 559                       0                    05
# ...                     ...                   ...
# 45352                     0                    05
# 45487                     0                    15
# 45520                     0                    05
# 45522                     0                    10
# 45581                     0                    05
#
# [841 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                       0
# Time_Order_picked                 0
# Weather_conditions              564
# Road_traffic_density            552
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             988
# Festival                        226
# City                           1196
# Time_taken (min)                  0
# Time_Orderd_hh                    0
# Time_Orderd_mm                    0
# Time_Order_picked_hh              0
# Time_Order_picked_mm              0
# dtype: int64

# %%
df['orderd'] = df['Time_Orderd_hh'].astype('str') + ':' + df['Time_Orderd_mm'].astype('str')

df['picked'] = df['Time_Order_picked_hh'].astype('str') + ':' + df['Time_Order_picked_mm'].astype('str')

# %%
df.head()
### ----- features selection-------
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0      DEHRES17DEL01                 36.0                      4.2  \
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked  ...
# 0                    78.116106   12-02-22       21:55             22:10  ...  \
# 1                    76.347589   13-02-22       14:55             15:05  ...
# 2                    74.006619   04-03-22       17:30             17:40  ...
# 3                    75.829346   13-02-22        9:20              9:30  ...
# 4                    80.502929   14-02-22       19:50             20:05  ...
#
#   multiple_deliveries Festival           City Time_taken (min) Time_Orderd_hh
# 0                 3.0       No  Metropolitian               46             21  \
# 1                 1.0       No  Metropolitian               23             14
# 2                 1.0       No  Metropolitian               21             17
# 3                 0.0       No  Metropolitian               20              9
# 4                 1.0       No  Metropolitian               41             19
#
#    Time_Orderd_mm Time_Order_picked_hh Time_Order_picked_mm  orderd  picked
# 0              55                   22                   10   21:55   22:10
# 1              55                   15                   05   14:55   15:05
# 2              30                   17                   40   17:30   17:40
# 3              20                    9                   30    9:20    9:30
# 4              50                   20                   05   19:50   20:05
#
# [5 rows x 25 columns]

# %%
# import seaborn as sns
# sns.pairplot(df)

# %%
# df.drop(['Delivery_person_ID','Order_Date'], inplace=True, axis=1)

# %%
df.drop(['Time_Orderd','Time_Order_picked','Time_Orderd_hh','Time_Orderd_mm','Time_Order_picked_hh','Time_Order_picked_mm'],inplace=True, axis=1)

# %%
df.isnull().sum()
# Out:
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Weather_conditions              564
# Road_traffic_density            552
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             988
# Festival                        226
# City                           1196
# Time_taken (min)                  0
# orderd                            0
# picked                            0
# dtype: int64

# %%
from datetime import time


# df['orderd_time'] = time(df['orderd'], format="%H:%M")
# df['picked_time'] = time(df['picked'], format="%H:%M")



# # dt.datetime(df['Time_Order_picked'], '%m/%d/%y %H:%M:%S')
# df['orderd_time']=df['orderd'].map(lambda x: dt.time.fromisoformat(x, '%H:%M'))

df['orderd'] = pd.to_datetime(df['orderd'],format='%H:%M').dt.time
df['picked'] = pd.to_datetime(df['picked'],format='%H:%M').dt.time

# %%
df.isnull().sum()
# Out:
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Weather_conditions              564
# Road_traffic_density            552
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             988
# Festival                        226
# City                           1196
# Time_taken (min)                  0
# orderd                            0
# picked                            0
# dtype: int64

# %%
df['Weather_conditions'].unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny', nan],
#       dtype=object)

# %%
df['Weather_conditions'].mode()
# Out:
# 0    Fog
# Name: Weather_conditions, dtype: object

# %%
df['Weather_conditions'].value_counts()
# Out:
# Weather_conditions
# Fog           7630
# Stormy        7557
# Cloudy        7508
# Sandstorms    7475
# Windy         7408
# Sunny         7263
# Name: count, dtype: int64

# %%
#filling most frequent values
df['Weather_conditions'].fillna('Fog',inplace=True)

# %%
df.isnull().sum()
# Out:
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Weather_conditions                0
# Road_traffic_density            552
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             988
# Festival                        226
# City                           1196
# Time_taken (min)                  0
# orderd                            0
# picked                            0
# dtype: int64

# %%
df['Road_traffic_density'].unique()
# Out:
# array(['Jam', 'High', 'Medium', 'Low', nan], dtype=object)

# %%
df['Road_traffic_density'].value_counts()
# Out:
# Road_traffic_density
# Low       15425
# Jam       14094
# Medium    10923
# High       4411
# Name: count, dtype: int64

# %%
#filling most frequent values
df['Road_traffic_density'].fillna('Low',inplace=True)

# %%
df.isnull().sum()
# Out:
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             988
# Festival                        226
# City                           1196
# Time_taken (min)                  0
# orderd                            0
# picked                            0
# dtype: int64

# %%
df['multiple_deliveries'].unique()
# Out:
# array([ 3.,  1.,  0., nan,  2.])

# %%
df['multiple_deliveries'].fillna(0,inplace=True)

# %%
sns.histplot(df['multiple_deliveries'], kde=True)
plt.show()

# %%
df['Road_traffic_density'].fillna(1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45405 entries, 0 to 45583
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_ID           45405 non-null  object
#  1   Delivery_person_Age          45405 non-null  float64
#  2   Delivery_person_Ratings      45405 non-null  float64
#  3   Restaurant_latitude          45405 non-null  float64
#  4   Restaurant_longitude         45405 non-null  float64
#  5   Delivery_location_latitude   45405 non-null  float64
#  6   Delivery_location_longitude  45405 non-null  float64
#  7   Order_Date                   45405 non-null  object
#  8   Weather_conditions           45405 non-null  object
#  9   Road_traffic_density         45405 non-null  object
#  10  Vehicle_condition            45405 non-null  int64
#  11  Type_of_order                45405 non-null  object
#  12  Type_of_vehicle              45405 non-null  object
#  13  multiple_deliveries          45405 non-null  float64
#  14  Festival                     45179 non-null  object
#  15  City                         44209 non-null  object
#  16  Time_taken (min)             45405 non-null  int64
#  17  orderd                       45405 non-null  object
#  18  picked                       45405 non-null  object
# dtypes: float64(7), int64(2), object(10)
# memory usage: 7.9+ MB

# %%
df['Festival'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['Festival'].fillna('No',inplace=True)

# %%
df['City'].unique()
# Out:
# array(['Metropolitian', 'Urban', 'Semi-Urban', nan], dtype=object)

# %%
df['City'].value_counts()
# Out:
# City
# Metropolitian    33946
# Urban            10100
# Semi-Urban         163
# Name: count, dtype: int64

# %%
#filling most frequent values
df['City'].fillna('Metropolitian',inplace=True)

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0      DEHRES17DEL01                 36.0                      4.2  \
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Weather_conditions
# 0                    78.116106   12-02-22                Fog  \
# 1                    76.347589   13-02-22             Stormy
# 2                    74.006619   04-03-22         Sandstorms
# 3                    75.829346   13-02-22         Sandstorms
# 4                    80.502929   14-02-22                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle
# 0                  Jam                  2         Snack      motorcycle  \
# 1                 High                  1          Meal      motorcycle
# 2               Medium                  1        Drinks         scooter
# 3                  Low                  0        Buffet      motorcycle
# 4                  Jam                  1         Snack         scooter
#
#    multiple_deliveries Festival           City  Time_taken (min)    orderd
# 0                  3.0       No  Metropolitian                46  21:55:00  \
# 1                  1.0       No  Metropolitian                23  14:55:00
# 2                  1.0       No  Metropolitian                21  17:30:00
# 3                  0.0       No  Metropolitian                20  09:20:00
# 4                  1.0       No  Metropolitian                41  19:50:00
#
#      picked
# 0  22:10:00
# 1  15:05:00
# 2  17:40:00
# 3  09:30:00
# 4  20:05:00

# %%
from sklearn.metrics import DistanceMetric
from math import radians

dist = DistanceMetric.get_metric('haversine')

lat1, lon1, lat2, lon2, R = 20.9467,-72.9520, -21.1702, 72.8311, 6373.0
    
X = [[radians(lat1), radians(lon1)], [radians(lat2), radians(lon2)]]
distance_sklearn = R * dist.pairwise(X)
print('distance using sklearn: ', np.array(distance_sklearn).item(1))
# Out:
# distance using sklearn:  16476.556554262424

# %%
# def cal_distance(lat1, lon1, lat2, lon2):
from math import sin, cos, sqrt, atan2, radians

lat1, lon1, lat2, lon2, R = 20.9467,-72.9520, -21.1702, 72.8311, 6373.0

dlon = radians(lon2) - radians(lon1)
dlat = radians(lat2) - radians(lat1)
    
a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
c = 2 * atan2(sqrt(a), sqrt(1 - a))
    
distance_haversine_formula = R * c
print('distance using haversine formula: ', distance_haversine_formula)
# Out:
# distance using haversine formula:  9268.016129132393

# %%
def cal_distance(lat1, lon1, lat2, lon2):
    R=6373.0
    
    X = [[radians(lat1), radians(lon1)], [radians(lat2), radians(lon2)]]
    distance_sklearn = R * dist.pairwise(X)
    return np.array(distance_sklearn).item(1)

# %% [markdown]
# Observation is latitude and logitude are given wrong in 399 rows..
# so and city are local - all belongs to india only...
# distance impact the result that is delivery time estimation most.. so dropping this rows..

# %%
#dropping negative values latitude
df = df.loc[~((df['Restaurant_latitude'] < 0) | 
              (df['Restaurant_longitude'] < 0) | 
              (df['Delivery_location_latitude'] < 0) | 
              (df['Delivery_location_longitude'] < 0))]

# %%
# counting distance..


df['distance'] = df.apply(lambda x: cal_distance(x['Restaurant_latitude'], x['Restaurant_longitude'],  x['Delivery_location_latitude'],  x['Delivery_location_longitude']), axis=1)
# Out:
# C:\Users\Darshi\AppData\Local\Temp\ipykernel_2032\3760746259.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['distance'] = df.apply(lambda x: cal_distance(x['Restaurant_latitude'], x['Restaurant_longitude'],  x['Delivery_location_latitude'],  x['Delivery_location_longitude']), axis=1)

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0      DEHRES17DEL01                 36.0                      4.2  \
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Weather_conditions
# 0                    78.116106   12-02-22                Fog  \
# 1                    76.347589   13-02-22             Stormy
# 2                    74.006619   04-03-22         Sandstorms
# 3                    75.829346   13-02-22         Sandstorms
# 4                    80.502929   14-02-22                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle
# 0                  Jam                  2         Snack      motorcycle  \
# 1                 High                  1          Meal      motorcycle
# 2               Medium                  1        Drinks         scooter
# 3                  Low                  0        Buffet      motorcycle
# 4                  Jam                  1         Snack         scooter
#
#    multiple_deliveries Festival           City  Time_taken (min)    orderd
# 0                  3.0       No  Metropolitian                46  21:55:00  \
# 1                  1.0       No  Metropolitian                23  14:55:00
# 2                  1.0       No  Metropolitian                21  17:30:00
# 3                  0.0       No  Metropolitian                20  09:20:00
# 4                  1.0       No  Metropolitian                41  19:50:00
#
#      picked   distance
# 0  22:10:00  10.283809
# 1  15:05:00   6.244278
# 2  17:40:00  13.792189
# 3  09:30:00   2.931178
# 4  20:05:00  19.402707

# %%
df.loc[df['distance']>50]
# Out:
# Empty DataFrame
# Columns: [Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_Date, Weather_conditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken (min), orderd, picked, distance]
# Index: []

# %%
# now we dont need 4 columns Restaurant_latitude Restaurant_longitude Delivery_location_latitude Delivery_location_longitude
df.drop(columns=['Restaurant_latitude'], inplace=True)
df.drop(columns=['Restaurant_longitude'], inplace=True)
df.drop(columns=['Delivery_location_latitude'], inplace=True)
df.drop(columns=['Delivery_location_longitude'], inplace=True)
# Out:
# C:\Users\Darshi\AppData\Local\Temp\ipykernel_2032\3412428988.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Restaurant_latitude'], inplace=True)
# C:\Users\Darshi\AppData\Local\Temp\ipykernel_2032\3412428988.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Restaurant_longitude'], inplace=True)
# C:\Users\Darshi\AppData\Local\Temp\ipykernel_2032\3412428988.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Delivery_location_latitude'], inplace=True)
# C:\Users\Darshi\AppData\Local\Temp\ipykernel_2032\3412428988.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Delivery_location_longitude'], inplace=True)

# %%
df[df['distance'] == df['distance'].max()]
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 903        ALHRES12DEL03                 22.0                      4.7  \
# 15701      ALHRES12DEL03                 22.0                      5.0
# 25917      ALHRES12DEL03                 32.0                      3.8
#
#       Order_Date Weather_conditions Road_traffic_density  Vehicle_condition
# 903     16-02-22             Cloudy                  Low                  2  \
# 15701   12-02-22         Sandstorms                  Low                  1
# 25917   14-02-22         Sandstorms                  Jam                  2
#
#       Type_of_order   Type_of_vehicle  multiple_deliveries Festival
# 903          Drinks  electric_scooter                  0.0       No  \
# 15701          Meal        motorcycle                  0.0       No
# 25917         Snack        motorcycle                  1.0       No
#
#                 City  Time_taken (min)    orderd    picked   distance
# 903    Metropolitian                26  22:55:00  23:10:00  20.976072
# 15701          Urban                12  22:10:00  22:15:00  20.976072
# 25917          Urban                33  20:25:00  20:30:00  20.976072

# %%
df['Vehicle_condition'].unique()
# Out:
# array([2, 1, 0, 3], dtype=int64)

# %%
# number of order citywise..
gr = df.groupby('City')['Delivery_person_ID'].count()
gr
# Out:
# City
# Metropolitian    34840
# Semi-Urban         162
# Urban            10004
# Name: Delivery_person_ID, dtype: int64

# %%
#number of order citywise..
plt.suptitle('Most order city wise', fontsize=15, fontweight='bold', alpha=0.8, y=1.)
df['City'].value_counts().plot.pie(figsize=(5,5),autopct='%1.1f%%') # most education degree...
# Out:
# <Axes: ylabel='count'>

# %%
#number of order citywise..
plt.suptitle('Type of order', fontsize=15, fontweight='bold', alpha=0.8, y=1.)
df['Type_of_order'].value_counts().plot.pie(figsize=(5,5),autopct='%1.1f%%') # most education degree...
# Out:
# <Axes: ylabel='count'>

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings Order_Date
# 0      DEHRES17DEL01                 36.0                      4.2   12-02-22  \
# 1      KOCRES16DEL01                 21.0                      4.7   13-02-22
# 2     PUNERES13DEL03                 23.0                      4.7   04-03-22
# 3     LUDHRES15DEL02                 34.0                      4.3   13-02-22
# 4      KNPRES14DEL02                 24.0                      4.7   14-02-22
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order
# 0                Fog                  Jam                  2         Snack  \
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City
# 0      motorcycle                  3.0       No  Metropolitian  \
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)    orderd    picked   distance
# 0                46  21:55:00  22:10:00  10.283809
# 1                23  14:55:00  15:05:00   6.244278
# 2                21  17:30:00  17:40:00  13.792189
# 3                20  09:20:00  09:30:00   2.931178
# 4                41  19:50:00  20:05:00  19.402707

# %%
#number of people with income ratio
plt.figure(figsize=(5, 5))
plt.suptitle('Number of order during festival seasons  ', fontsize=15, fontweight='bold', alpha=0.8, y=1.)
gr = sns.countplot(x = df['Festival'])

abs_values = df['Festival'].value_counts(ascending=False).values

gr.bar_label(container=gr.containers[0], labels=abs_values)
# Out:
# [Text(0, 0, '44121'), Text(0, 0, '885')]

# %%
gr = df.groupby('Delivery_person_ID')['Delivery_person_ID'].count()

# %%
# finding maximum orders delivered by which ID and how many...
gr[gr==gr.max()]
# Out:
# Delivery_person_ID
# JAPRES11DEL02    67
# Name: Delivery_person_ID, dtype: int64

# %%
df.groupby('Weather_conditions')['Weather_conditions'].count().sort_values(ascending=False)


# Set up a grid of plots
fig = plt.figure(figsize=(10,10)) 
fig_dims = (3, 2)
# Plot accidents depending on type
plt.subplot2grid(fig_dims, (0, 0))
df.groupby('Weather_conditions')['Weather_conditions'].value_counts().plot(kind='bar', 
                                     title='Weather Condition wise orders count')
# Out:
# <Axes: title={'center': 'Weather Condition wise orders count'}, xlabel='Weather_conditions'>

# %%
# number of delivery done by delivery man in this data set
gr = df.groupby('Delivery_person_ID')['Delivery_person_ID'].value_counts(ascending=False)
gr
# Out:
# Delivery_person_ID
# AGRRES010DEL01    13
# AGRRES010DEL02    15
# AGRRES010DEL03    13
# AGRRES01DEL01     11
# AGRRES01DEL02     14
#                   ..
# VADRES19DEL02     59
# VADRES19DEL03     40
# VADRES20DEL01     59
# VADRES20DEL02     50
# VADRES20DEL03     35
# Name: count, Length: 1320, dtype: int64

# %%
df
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0          DEHRES17DEL01                 36.0                      4.2  \
# 1          KOCRES16DEL01                 21.0                      4.7
# 2         PUNERES13DEL03                 23.0                      4.7
# 3         LUDHRES15DEL02                 34.0                      4.3
# 4          KNPRES14DEL02                 24.0                      4.7
# ...                  ...                  ...                      ...
# 45579      JAPRES04DEL01                 30.0                      4.8
# 45580      AGRRES16DEL01                 21.0                      4.6
# 45581     CHENRES08DEL03                 30.0                      4.9
# 45582    COIMBRES11DEL01                 20.0                      4.7
# 45583   RANCHIRES09DEL02                 23.0                      4.9
#
#       Order_Date Weather_conditions Road_traffic_density  Vehicle_condition
# 0       12-02-22                Fog                  Jam                  2  \
# 1       13-02-22             Stormy                 High                  1
# 2       04-03-22         Sandstorms               Medium                  1
# 3       13-02-22         Sandstorms                  Low                  0
# 4       14-02-22                Fog                  Jam                  1
# ...          ...                ...                  ...                ...
# 45579   24-03-22              Windy                 High                  1
# 45580   16-02-22              Windy                  Jam                  0
# 45581   11-03-22             Cloudy                  Low                  1
# 45582   07-03-22             Cloudy                 High                  0
# 45583   02-03-22                Fog               Medium                  2
#
#       Type_of_order Type_of_vehicle  multiple_deliveries Festival
# 0             Snack      motorcycle                  3.0       No  \
# 1              Meal      motorcycle                  1.0       No
# 2            Drinks         scooter                  1.0       No
# 3            Buffet      motorcycle                  0.0       No
# 4             Snack         scooter                  1.0       No
# ...             ...             ...                  ...      ...
# 45579          Meal      motorcycle                  0.0       No
# 45580        Buffet      motorcycle                  1.0       No
# 45581        Drinks         scooter                  0.0       No
# 45582         Snack      motorcycle                  1.0       No
# 45583         Snack         scooter                  1.0       No
#
#                 City  Time_taken (min)    orderd    picked   distance
# 0      Metropolitian                46  21:55:00  22:10:00  10.283809
# 1      Metropolitian                23  14:55:00  15:05:00   6.244278
# 2      Metropolitian                21  17:30:00  17:40:00  13.792189
# 3      Metropolitian                20  09:20:00  09:30:00   2.931178
# 4      Metropolitian                41  19:50:00  20:05:00  19.402707
# ...              ...               ...       ...       ...        ...
# 45579  Metropolitian                32  11:35:00  11:45:00   1.490314
# 45580  Metropolitian                36  19:55:00  20:10:00  11.011190
# 45581  Metropolitian                16  23:50:00  00:05:00   4.658657
# 45582  Metropolitian                26  13:35:00  13:40:00   6.234350
# 45583  Metropolitian                36  17:10:00  17:15:00  12.078186
#
# [45006 rows x 16 columns]

# %%
df[df['Time_taken (min)'] == df['Time_taken (min)'].max()]
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 179        MYSRES04DEL03                 38.0                      4.3  \
# 632       LUDHRES18DEL03                 20.0                      3.9
# 2364      CHENRES04DEL01                 31.0                      4.9
# 3094       JAPRES09DEL01                 39.0                      4.7
# 3702       MYSRES11DEL03                 24.0                      4.5
# ...                  ...                  ...                      ...
# 43528      VADRES18DEL02                 31.0                      4.7
# 43659     PUNERES13DEL02                 32.0                      4.3
# 43921     PUNERES12DEL02                 38.0                      4.5
# 44274      MUMRES05DEL01                 36.0                      4.8
# 45034      MUMRES15DEL02                 39.0                      4.4
#
#       Order_Date Weather_conditions Road_traffic_density  Vehicle_condition
# 179     04-04-22         Sandstorms                  Jam                  0  \
# 632     11-02-22              Sunny                  Jam                  0
# 2364    06-04-22                Fog                  Jam                  0
# 3094    23-03-22                Fog                  Jam                  0
# 3702    15-03-22              Sunny                  Jam                  0
# ...          ...                ...                  ...                ...
# 43528   06-03-22             Cloudy                  Jam                  0
# 43659   04-03-22         Sandstorms                  Jam                  0
# 43921   10-03-22             Cloudy                  Jam                  0
# 44274   06-03-22             Stormy                  Jam                  0
# 45034   02-04-22         Sandstorms                  Jam                  0
#
#       Type_of_order Type_of_vehicle  multiple_deliveries Festival
# 179            Meal      motorcycle                  1.0      Yes  \
# 632          Buffet      motorcycle                  1.0       No
# 2364          Snack      motorcycle                  0.0       No
# 3094         Buffet      motorcycle                  3.0      Yes
# 3702         Drinks      motorcycle                  0.0       No
# ...             ...             ...                  ...      ...
# 43528          Meal      motorcycle                  1.0       No
# 43659         Snack      motorcycle                  0.0       No
# 43921        Drinks      motorcycle                  2.0      Yes
# 44274        Buffet      motorcycle                  3.0       No
# 45034          Meal      motorcycle                  1.0       No
#
#                 City  Time_taken (min)    orderd    picked   distance
# 179       Semi-Urban                54  21:15:00  21:25:00  13.994309
# 632    Metropolitian                54  20:40:00  20:45:00   8.793120
# 2364   Metropolitian                54  21:50:00  21:55:00  17.080147
# 3094      Semi-Urban                54  21:45:00  21:55:00  16.389646
# 3702   Metropolitian                54  21:30:00  21:35:00   9.329544
# ...              ...               ...       ...       ...        ...
# 43528  Metropolitian                54  19:20:00  19:35:00  20.449347
# 43659     Semi-Urban                54  20:25:00  20:30:00  12.259894
# 43921  Metropolitian                54  21:20:00  21:35:00  12.261338
# 44274  Metropolitian                54  21:25:00  21:40:00  10.716574
# 45034  Metropolitian                54  21:05:00  21:05:00  12.238663
#
# [88 rows x 16 columns]

# %%
sample = df[df['Time_taken (min)'] == 54]
sample.groupby('City')['Road_traffic_density'].value_counts()
# Out:
# City           Road_traffic_density
# Metropolitian  Jam                     60
#                High                     3
#                Low                      1
# Semi-Urban     Jam                     15
#                High                     2
# Urban          Jam                      6
#                High                     1
# Name: count, dtype: int64

# %%
sns.kdeplot(x='Time_taken (min)', data=df, hue='Road_traffic_density')
# Out:
# <Axes: xlabel='Time_taken (min)', ylabel='Density'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45006 entries, 0 to 45583
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Delivery_person_ID       45006 non-null  object
#  1   Delivery_person_Age      45006 non-null  float64
#  2   Delivery_person_Ratings  45006 non-null  float64
#  3   Order_Date               45006 non-null  object
#  4   Weather_conditions       45006 non-null  object
#  5   Road_traffic_density     45006 non-null  object
#  6   Vehicle_condition        45006 non-null  int64
#  7   Type_of_order            45006 non-null  object
#  8   Type_of_vehicle          45006 non-null  object
#  9   multiple_deliveries      45006 non-null  float64
#  10  Festival                 45006 non-null  object
#  11  City                     45006 non-null  object
#  12  Time_taken (min)         45006 non-null  int64
#  13  orderd                   45006 non-null  object
#  14  picked                   45006 non-null  object
#  15  distance                 45006 non-null  float64
# dtypes: float64(4), int64(2), object(10)
# memory usage: 5.8+ MB

# %%
df['orderd']
# Out:
# 0        21:55:00
# 1        14:55:00
# 2        17:30:00
# 3        09:20:00
# 4        19:50:00
#            ...
# 45579    11:35:00
# 45580    19:55:00
# 45581    23:50:00
# 45582    13:35:00
# 45583    17:10:00
# Name: orderd, Length: 45006, dtype: object

# %%
df['start_time'] = pd.to_datetime(df['orderd'], format='%H:%M:%S')
df['end_time'] = pd.to_datetime(df['picked'], format='%H:%M:%S')

# calculate time difference and extract hours and minutes
df['time_diff'] = df['end_time'] - df['start_time']
# df['time_diff_hours'] = df['time_diff'].dt.seconds // 3600
df['time_diff_minutes'] = (df['time_diff'].dt.seconds % 3600) // 60
# Out:
# C:\Users\Darshi\AppData\Local\Temp\ipykernel_2032\3401902918.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_time'] = pd.to_datetime(df['orderd'], format='%H:%M:%S')
# C:\Users\Darshi\AppData\Local\Temp\ipykernel_2032\3401902918.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end_time'] = pd.to_datetime(df['picked'], format='%H:%M:%S')
# C:\Users\Darshi\AppData\Local\Temp\ipykernel_2032\3401902918.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['time_diff'] = df['end_time'] - df['start_time']
# C:\Users\Darshi\AppData\Local\Temp\ipykernel_2032\3401902918.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['time_diff_minutes'] = (df['time_diff'].dt.seconds % 3600) // 60

# %%
# df.loc(df['time_diff_minutes']==df['time_diff_minutes'].max())
df[df['time_diff_minutes'] == df['time_diff_minutes'].max()]
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0          DEHRES17DEL01                 36.0                      4.2  \
# 4          KNPRES14DEL02                 24.0                      4.7
# 6          MYSRES01DEL01                 35.0                      4.0
# 9          KOLRES15DEL03                 21.0                      4.7
# 11      RANCHIRES06DEL02                 31.0                      4.7
# ...                  ...                  ...                      ...
# 45572      SURRES02DEL03                 20.0                      4.9
# 45575     CHENRES08DEL02                 37.0                      4.8
# 45576      KNPRES03DEL01                 30.0                      4.2
# 45580      AGRRES16DEL01                 21.0                      4.6
# 45581     CHENRES08DEL03                 30.0                      4.9
#
#       Order_Date Weather_conditions Road_traffic_density  Vehicle_condition
# 0       12-02-22                Fog                  Jam                  2  \
# 4       14-02-22                Fog                  Jam                  1
# 6       01-03-22              Windy                 High                  1
# 9       15-02-22              Windy                  Jam                  0
# 11      10-03-22         Sandstorms                  Low                  2
# ...          ...                ...                  ...                ...
# 45572   03-03-22         Sandstorms                  Jam                  2
# 45575   05-04-22         Sandstorms                  Low                  2
# 45576   14-02-22             Cloudy               Medium                  1
# 45580   16-02-22              Windy                  Jam                  0
# 45581   11-03-22             Cloudy                  Low                  1
#
#       Type_of_order   Type_of_vehicle  multiple_deliveries Festival
# 0             Snack        motorcycle                  3.0       No  \
# 4             Snack           scooter                  1.0       No
# 6              Meal           scooter                  1.0       No
# 9              Meal        motorcycle                  1.0       No
# 11             Meal  electric_scooter                  0.0       No
# ...             ...               ...                  ...      ...
# 45572        Drinks        motorcycle                  1.0       No
# 45575        Drinks  electric_scooter                  0.0       No
# 45576         Snack        motorcycle                  2.0      Yes
# 45580        Buffet        motorcycle                  1.0       No
# 45581        Drinks           scooter                  0.0       No
#
#                 City  Time_taken (min)    orderd    picked   distance
# 0      Metropolitian                46  21:55:00  22:10:00  10.283809  \
# 4      Metropolitian                41  19:50:00  20:05:00  19.402707
# 6      Metropolitian                33  14:55:00  15:10:00   6.219953
# 9              Urban                15  21:15:00  21:30:00   4.542000
# 11     Metropolitian                26  22:30:00  22:45:00  19.624898
# ...              ...               ...       ...       ...        ...
# 45572          Urban                18  20:25:00  20:40:00   4.562170
# 45575  Metropolitian                20  09:35:00  09:50:00   3.105802
# 45576  Metropolitian                42  18:10:00  18:25:00  10.448604
# 45580  Metropolitian                36  19:55:00  20:10:00  11.011190
# 45581  Metropolitian                16  23:50:00  00:05:00   4.658657
#
#                start_time            end_time         time_diff
# 0     1900-01-01 21:55:00 1900-01-01 22:10:00   0 days 00:15:00  \
# 4     1900-01-01 19:50:00 1900-01-01 20:05:00   0 days 00:15:00
# 6     1900-01-01 14:55:00 1900-01-01 15:10:00   0 days 00:15:00
# 9     1900-01-01 21:15:00 1900-01-01 21:30:00   0 days 00:15:00
# 11    1900-01-01 22:30:00 1900-01-01 22:45:00   0 days 00:15:00
# ...                   ...                 ...               ...
# 45572 1900-01-01 20:25:00 1900-01-01 20:40:00   0 days 00:15:00
# 45575 1900-01-01 09:35:00 1900-01-01 09:50:00   0 days 00:15:00
# 45576 1900-01-01 18:10:00 1900-01-01 18:25:00   0 days 00:15:00
# 45580 1900-01-01 19:55:00 1900-01-01 20:10:00   0 days 00:15:00
# 45581 1900-01-01 23:50:00 1900-01-01 00:05:00 -1 days +00:15:00
#
#        time_diff_minutes
# 0                     15
# 4                     15
# 6                     15
# 9                     15
# 11                    15
# ...                  ...
# 45572                 15
# 45575                 15
# 45576                 15
# 45580                 15
# 45581                 15
#
# [11874 rows x 20 columns]

# %%
#fetching categorical/string columns only...
categorical_features = [feature for feature in df.columns if df[feature].dtype =='O']
# fetching numeric columns list
numeric_features = [feature for feature in df.columns if df[feature].dtype =='int64'] 

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
x=0

for i in numeric_features:
    sns.displot(df[i])
    print('\n')
    plt.show()

# %%
# for i in categorical_features:
#     sns.displot(df[i])
#     print('\n')
#     plt.show()

# %%
copy_df = df
# df = copy_df

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings Order_Date
# 0      DEHRES17DEL01                 36.0                      4.2   12-02-22  \
# 1      KOCRES16DEL01                 21.0                      4.7   13-02-22
# 2     PUNERES13DEL03                 23.0                      4.7   04-03-22
# 3     LUDHRES15DEL02                 34.0                      4.3   13-02-22
# 4      KNPRES14DEL02                 24.0                      4.7   14-02-22
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order
# 0                Fog                  Jam                  2         Snack  \
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City
# 0      motorcycle                  3.0       No  Metropolitian  \
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)    orderd    picked   distance          start_time
# 0                46  21:55:00  22:10:00  10.283809 1900-01-01 21:55:00  \
# 1                23  14:55:00  15:05:00   6.244278 1900-01-01 14:55:00
# 2                21  17:30:00  17:40:00  13.792189 1900-01-01 17:30:00
# 3                20  09:20:00  09:30:00   2.931178 1900-01-01 09:20:00
# 4                41  19:50:00  20:05:00  19.402707 1900-01-01 19:50:00
#
#              end_time       time_diff  time_diff_minutes
# 0 1900-01-01 22:10:00 0 days 00:15:00                 15
# 1 1900-01-01 15:05:00 0 days 00:10:00                 10
# 2 1900-01-01 17:40:00 0 days 00:10:00                 10
# 3 1900-01-01 09:30:00 0 days 00:10:00                 10
# 4 1900-01-01 20:05:00 0 days 00:15:00                 15

# %%
# dropping unnecessary columns...
df.drop(columns=['Delivery_person_ID','Order_Date','Type_of_vehicle','Festival','orderd','picked','time_diff','start_time','end_time'], inplace=True)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions
# 0                 36.0                      4.2                Fog  \
# 1                 21.0                      4.7             Stormy
# 2                 23.0                      4.7         Sandstorms
# 3                 34.0                      4.3         Sandstorms
# 4                 24.0                      4.7                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_order  multiple_deliveries
# 0                  Jam                  2         Snack                  3.0  \
# 1                 High                  1          Meal                  1.0
# 2               Medium                  1        Drinks                  1.0
# 3                  Low                  0        Buffet                  0.0
# 4                  Jam                  1         Snack                  1.0
#
#             City  Time_taken (min)   distance  time_diff_minutes
# 0  Metropolitian                46  10.283809                 15
# 1  Metropolitian                23   6.244278                 10
# 2  Metropolitian                21  13.792189                 10
# 3  Metropolitian                20   2.931178                 10
# 4  Metropolitian                41  19.402707                 15

# %%
df = df.reindex(columns=['Delivery_person_Age', 'Delivery_person_Ratings', 'Weather_conditions','Road_traffic_density','Vehicle_condition','Type_of_order','multiple_deliveries','City','distance','time_diff_minutes','Time_taken (min)'])

# %%
df.head(5)
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions
# 0                 36.0                      4.2                Fog  \
# 1                 21.0                      4.7             Stormy
# 2                 23.0                      4.7         Sandstorms
# 3                 34.0                      4.3         Sandstorms
# 4                 24.0                      4.7                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_order  multiple_deliveries
# 0                  Jam                  2         Snack                  3.0  \
# 1                 High                  1          Meal                  1.0
# 2               Medium                  1        Drinks                  1.0
# 3                  Low                  0        Buffet                  0.0
# 4                  Jam                  1         Snack                  1.0
#
#             City   distance  time_diff_minutes  Time_taken (min)
# 0  Metropolitian  10.283809                 15                46
# 1  Metropolitian   6.244278                 10                23
# 2  Metropolitian  13.792189                 10                21
# 3  Metropolitian   2.931178                 10                20
# 4  Metropolitian  19.402707                 15                41

# %%
df.to_csv('./data/restaurant_cleaned.csv')

# %%
# from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()
# ohe.fit_transform(df[['Weather_conditions']]).toarray()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 2
#       1 # from sklearn.preprocessing import OneHotEncoder
# ----> 2 ohe=OneHotEncoder()
#       3 # ohe.fit_transform(df[['Weather_conditions']]).toarray()
#
# NameError: name 'OneHotEncoder' is not defined

# %%
## Replacing target guided ordinal encoding
def replace_Weather_conditions_with_mean(df):
    mean_prices = df.groupby('Weather_conditions')['Time_taken (min)'].mean().sort_values()
    df['Weather_conditions'] = df['Weather_conditions'].apply(lambda x: mean_prices[x])
    return df

df = replace_Weather_conditions_with_mean(df)
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Weather_conditions
# 0                 36.0                      4.2           28.807064  \
# 1                 21.0                      4.7           25.858055
# 2                 23.0                      4.7           25.868031
# 3                 34.0                      4.3           25.868031
# 4                 24.0                      4.7           28.807064
#
#   Road_traffic_density  Vehicle_condition Type_of_order  multiple_deliveries
# 0                  Jam                  2         Snack                  3.0  \
# 1                 High                  1          Meal                  1.0
# 2               Medium                  1        Drinks                  1.0
# 3                  Low                  0        Buffet                  0.0
# 4                  Jam                  1         Snack                  1.0
#
#             City   distance  time_diff_minutes  Time_taken (min)
# 0  Metropolitian  10.283809                 15                46
# 1  Metropolitian   6.244278                 10                23
# 2  Metropolitian  13.792189                 10                21
# 3  Metropolitian   2.931178                 10                20
# 4  Metropolitian  19.402707                 15                41

# %%
ohe.fit_transform(df[['Road_traffic_density']]).toarray()
## Replacing target guided ordinal encoding
def replace_Road_traffic_density_with_mean(df):
    mean_prices = df.groupby('Road_traffic_density')['Time_taken (min)'].mean().sort_values()
    df['Road_traffic_density'] = df['Road_traffic_density'].apply(lambda x: mean_prices[x])
    return df

df = replace_Road_traffic_density_with_mean(df)
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Weather_conditions
# 0                 36.0                      4.2           28.807064  \
# 1                 21.0                      4.7           25.858055
# 2                 23.0                      4.7           25.868031
# 3                 34.0                      4.3           25.868031
# 4                 24.0                      4.7           28.807064
#
#    Road_traffic_density  Vehicle_condition Type_of_order  multiple_deliveries
# 0             31.177541                  2         Snack                  3.0  \
# 1             27.213358                  1          Meal                  1.0
# 2             26.709710                  1        Drinks                  1.0
# 3             21.411597                  0        Buffet                  0.0
# 4             31.177541                  1         Snack                  1.0
#
#             City   distance  time_diff_minutes  Time_taken (min)
# 0  Metropolitian  10.283809                 15                46
# 1  Metropolitian   6.244278                 10                23
# 2  Metropolitian  13.792189                 10                21
# 3  Metropolitian   2.931178                 10                20
# 4  Metropolitian  19.402707                 15                41

# %%
ohe.fit_transform(df[['Type_of_order']]).toarray()
## Replacing target guided ordinal encoding
def replace_Road_Type_of_order_with_mean(df):
    mean_prices = df.groupby('Type_of_order')['Time_taken (min)'].mean().sort_values()
    df['Type_of_order'] = df['Type_of_order'].apply(lambda x: mean_prices[x])
    return df

df = replace_Road_Type_of_order_with_mean(df)
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Weather_conditions
# 0                 36.0                      4.2           28.807064  \
# 1                 21.0                      4.7           25.858055
# 2                 23.0                      4.7           25.868031
# 3                 34.0                      4.3           25.868031
# 4                 24.0                      4.7           28.807064
#
#    Road_traffic_density  Vehicle_condition  Type_of_order
# 0             31.177541                  2      26.272320  \
# 1             27.213358                  1      26.433100
# 2             26.709710                  1      26.190472
# 3             21.411597                  0      26.286330
# 4             31.177541                  1      26.272320
#
#    multiple_deliveries           City   distance  time_diff_minutes
# 0                  3.0  Metropolitian  10.283809                 15  \
# 1                  1.0  Metropolitian   6.244278                 10
# 2                  1.0  Metropolitian  13.792189                 10
# 3                  0.0  Metropolitian   2.931178                 10
# 4                  1.0  Metropolitian  19.402707                 15
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
ohe.fit_transform(df[['City']]).toarray()
## Replacing target guided ordinal encoding
def replace_City_with_mean(df):
    mean_prices = df.groupby('City')['Time_taken (min)'].mean().sort_values()
    df['City'] = df['City'].apply(lambda x: mean_prices[x])
    return df

df = replace_City_with_mean(df)
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Weather_conditions
# 0                 36.0                      4.2           28.807064  \
# 1                 21.0                      4.7           25.858055
# 2                 23.0                      4.7           25.868031
# 3                 34.0                      4.3           25.868031
# 4                 24.0                      4.7           28.807064
#
#    Road_traffic_density  Vehicle_condition  Type_of_order
# 0             31.177541                  2      26.272320  \
# 1             27.213358                  1      26.433100
# 2             26.709710                  1      26.190472
# 3             21.411597                  0      26.286330
# 4             31.177541                  1      26.272320
#
#    multiple_deliveries       City   distance  time_diff_minutes
# 0                  3.0  27.138088  10.283809                 15  \
# 1                  1.0  27.138088   6.244278                 10
# 2                  1.0  27.138088  13.792189                 10
# 3                  0.0  27.138088   2.931178                 10
# 4                  1.0  27.138088  19.402707                 15
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
df.head(5)
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Weather_conditions
# 0                 36.0                      4.2           28.807064  \
# 1                 21.0                      4.7           25.858055
# 2                 23.0                      4.7           25.868031
# 3                 34.0                      4.3           25.868031
# 4                 24.0                      4.7           28.807064
#
#    Road_traffic_density  Vehicle_condition  Type_of_order
# 0             31.177541                  2      26.272320  \
# 1             27.213358                  1      26.433100
# 2             26.709710                  1      26.190472
# 3             21.411597                  0      26.286330
# 4             31.177541                  1      26.272320
#
#    multiple_deliveries       City   distance  time_diff_minutes
# 0                  3.0  27.138088  10.283809                 15  \
# 1                  1.0  27.138088   6.244278                 10
# 2                  1.0  27.138088  13.792189                 10
# 3                  0.0  27.138088   2.931178                 10
# 4                  1.0  27.138088  19.402707                 15
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
import matplotlib.pyplot as plt
import seaborn as sns

ig, ax = plt.subplots(figsize=(8, 8))

correlation_= df.corr()

axis_corr = sns.heatmap(
correlation_, 
vmin=-1, vmax=1, center=0,
cmap=sns.diverging_palette(180, 2000, n=500),
square=True, annot=True
)

plt.show()

# %%
# dropping not co-related columns...
df.drop(columns=['time_diff_minutes','Type_of_order'], inplace=True)

# %%
has_null = df.isnull().any().any()

if has_null:
    print("The dataframe has null values")
else:
    print("The dataframe does not have null values")
# Out:
# The dataframe does not have null values

# %%
from sklearn.model_selection import train_test_split

X = df.iloc[:, df.columns != 'Time_taken (min)'] # all rows, column last ignore -1 ---- creating independent features dataset
y = df.iloc[:,df.columns == 'Time_taken (min)'] # only last column                 ----- creating dependet features dataset

# %%
y['Time_taken (min)']
# Out:
# 0        46
# 1        23
# 2        21
# 3        20
# 4        41
#          ..
# 45579    32
# 45580    36
# 45581    16
# 45582    26
# 45583    36
# Name: Time_taken (min), Length: 45006, dtype: int64

# %%
X.shape
# Out:
# (45006, 8)

# %%
y.shape
# Out:
# (45006, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
X_train.shape, X_test.shape # total number of train dataset and test dataset
# Out:
# ((30154, 8), (14852, 8))

# %%
from sklearn.preprocessing import StandardScaler # standard deviationssss
scaler = StandardScaler()

# %%
scaler.fit(X_train) #calculate mean and standard deviation of all fatures
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train) # or both together scale.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.61220239,  0.82211675,  1.07013798, ...,  0.47178802,
#         -1.48399831,  1.87367324],
#        [-0.44161843,  0.51431467, -0.18357269, ..., -1.2618576 ,
#         -1.48399831, -0.34560936],
#        [ 0.43656559, -0.10128951,  1.07013798, ...,  0.47178802,
#         -1.48399831, -1.17819847],
#        ...,
#        [-0.96852884, -0.10128951, -0.07470949, ..., -1.2618576 ,
#          0.37609012, -0.65099641],
#        [-1.49543925,  0.51431467, -0.18782825, ...,  0.47178802,
#         -1.48399831, -1.46355722],
#        [ 1.1391128 , -1.64029995, -0.18357269, ...,  0.47178802,
#          0.37609012, -1.18623118]])

# %%
X_test = scaler.transform(X_test) # only transforminf into zscore based on train data for test

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_test)

# %%
y_pred # predicted data..
# Out:
# array([[17.67883705],
#        [30.94606108],
#        [24.18496692],
#        ...,
#        [15.25855686],
#        [24.65445953],
#        [18.10436374]])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import numpy as np
mse = mean_squared_error(y_test, y_pred)
print(mse)
mae = mean_absolute_error(y_test, y_pred)
print(mae)
print(np.sqrt(mse))
# Out:
# 39.02585242381274
# 4.946481763949947
# 6.247067505943308

# %%
from sklearn.metrics import r2_score

# %%
r2score = r2_score(y_test, y_pred)

# %%
r2score # linear regression r2 squares.... 56%
# Out:
# 0.5633835544419098

# %%
# adjusted r square
1 - (1-r2score)*(len(y)-1)/(len(y)-X.shape[1]-1)
# Out:
# 0.5633059285654188

# %%
# ridge regression application............
from sklearn.linear_model import Ridge
ridge = Ridge() # alpha is 1 by default..
ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
y_pred = ridge.predict(X_test)

# %%
r2score = r2_score(y_test, y_pred)  ## ridge regression values... 56%
r2score
# Out:
# 0.5633832336939962

# %%
mse = mean_squared_error(y_test, y_pred)
print(mse)
mae = mean_absolute_error(y_test, y_pred)
print(mae)
print(np.sqrt(mse))
# Out:
# 39.02588109305063
# 4.946484540029064
# 6.247069800558549

# %%
# lasso regressionnnnnnnnnnnnn
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(X_train, y_train)
# Out:
# Lasso()

# %%
y_pred = lasso.predict(X_test)

# %%
# lasso is giving u high error more than 1....
mse = mean_squared_error(y_test, y_pred)
print(mse)
mae = mean_absolute_error(y_test, y_pred)
print(mae)
print(np.sqrt(mse))
# Out:
# 45.178855686616004
# 5.335979295125723
# 6.721521828173736

# %%
r2score = r2_score(y_test, y_pred)  ## ridge regression values... 49%
r2score
# Out:
# 0.49454450936641403

# %%
# elasticnet regression..............

from sklearn.linear_model import ElasticNet
elasticnet = ElasticNet( alpha = 20.0)
elasticnet.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=20.0)

# %%
y_pred = elasticnet.predict(X_test)

# %%
# elasticnet is giving u high error more than 1....
mse = mean_squared_error(y_test, y_pred)
print(mse)
mae = mean_absolute_error(y_test, y_pred)
print(mae)
print(np.sqrt(mse))
# Out:
# 89.38704924152827
# 7.6464978564743005
# 9.454472446494742

# %%
r2score = r2_score(y_test, y_pred) 
r2score
# Out:
# -5.13325097311057e-05

# %% [markdown]
# conclusion is as below..
# 1. Most of the orders are from metropolitian cities..
# 2. all most all kind of order food type('Drinks, Buffet, MEal or snack) are in euqal quantity
#
# 3. Orders are more in normal days rather than festive seasons..(festival seasons does not affect much..)
# 4. maximum orders are delivered by 'JAPRES11DEL02' ID and maximum 67 orders are delivered by this ID-JAPRES11DEL02
# 5. maximum orders are during 'Fog'(Weather_condition) but number of orders are not much affected in different weather.. almost all are near to mean
# 6. Maximum time taken by total 91 orders.. and majority are delayed due to road_trafic Jam only..
#   metropolitian city has maximum road traffic jam
# 7. maximum time taken to prepared the order is 15 mins.. and 11913 orders took 15 min to prepared and dispath
# 8. some latitude and logitude of restaurant / delivery location are wrong which is major corelated to delivery time so delete 399 rows..

# %%
# Out:
# Failed to start the Kernel.
#
# Cannot execute code, session has been disposed.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# Failed to start the Kernel.
#
# Cannot execute code, session has been disposed.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
